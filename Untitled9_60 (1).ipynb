# %%
# !pip install sacrebleu

import torch
from transformers import MarianMTModel, MarianTokenizer
import logging
from datasets import load_dataset
import sacrebleu
import random

# Corrected logging call for transformers
from transformers import logging as transformers_logging
transformers_logging.set_verbosity_error()

dataset = load_dataset("opus100", "en-fr", split="test")
sample_indices = random.sample(range(len(dataset)), 15)
sampled_data = [dataset[i] for i in sample_indices]

english_sentences = [ex["translation"]["en"] for ex in sampled_data]
french_references = [[ex["translation"]["fr"]] for ex in sampled_data]
model_name = "Helsinki-NLP/opus-mt-en-fr"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)
model.config.tie_word_embeddings = False
inputs = tokenizer(
    english_sentences,
    return_tensors="pt",
    padding=True,
    truncation=True,
    max_length=128
)
with torch.no_grad():
    generated_tokens = model.generate(**inputs)
    translated_sentences = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
print("\n--- Translations ---\n")
for idx, (src, pred, ref) in enumerate(zip(english_sentences, translated_sentences, french_references), 1):
    print(f"Example {idx}")
    print(f"Source : {src}")
    print(f"Predicted : {pred}")
    print(f"Reference : {ref[0]}")
    print()
bleu_score = sacrebleu.corpus_bleu(translated_sentences, french_references)
print("BLEU Score:", bleu_score.score)
# Out:
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.12/dist-packages (2.6.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2025.11.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2.0.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (6.0.2)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# en-fr/test-00000-of-00001.parquet:   0%|          | 0.00/327k [00:00<?, ?B/s]
# en-fr/train-00000-of-00001.parquet:   0%|          | 0.00/142M [00:00<?, ?B/s]
# en-fr/validation-00000-of-00001.parquet:   0%|          | 0.00/334k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/1000000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/marian/tokenization_marian.py:176: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# --- Translations ---
#
# Example 1
# Source : 4-2001, point 1.6.47 Proposal for a Council decision on a Community position concerning a decision of the EC - the former Yugoslav Republic of Macedonia Stabilisation and Association Council amending Protocol 2 (on steel products) to the Stabilisation and Association Agreement: COM(2007) 437; point 1.29.15 of this Bulletin Adopted on 17 October.
# Predicted : 4-2001, point 1.6.47 Proposition de décision du Conseil relative à une position de la Communauté concernant une décision du Conseil de stabilisation et d'association CE-ancienne République yougoslave de Macédoine modifiant le protocole 2 (produits sidérurgiques) de l'accord de stabilisation et d'association - COM(2007) 437 et point 1.29.15 du présent Bulletin Adoption par le Conseil, le 17 octobre.
# Reference : 4-2001, point 1.6.47 Proposition de décision du Conseil concernant la position de la Communauté sur une décision du conseil de stabilisation et d'association CE-ancienne République yougoslave de Macédoine modifiant le protocole n° 2 (relatif aux produits sidérurgiques) à l'accord de stabilisation et d'association - COM(2007) 437 et point 1.29.15 du présent Bulletin Adoption par la Commission, le 17 octobre.
#
# Example 2
# Source : Taking into account the recommendations made by the EDPS in its Opinion, the Commission has developed a set of data protection guidelines for the EWRS, which should help to clarify the respective roles, tasks and obligations of the various actors of the system and in that way guarantee effective compliance with the abovementioned data protection rules and ensure the provision of clear information and easily available mechanisms for data subjects to assert their rights,
# Predicted : Compte tenu des recommandations formulées par le CEPD dans son avis, la Commission a élaboré un ensemble de lignes directrices pour la protection des données à l'intention du SEAE, qui devrait contribuer à clarifier les rôles, les tâches et les obligations respectifs des différents acteurs du système et garantir ainsi le respect effectif des règles susmentionnées en matière de protection des données et garantir la fourniture d'informations claires et de mécanismes facilement accessibles aux personnes concernées pour faire valoir leurs droits,
# Reference : Tenant compte des recommandations formulées par le CEPD dans son avis, la Commission a rédigé un ensemble de lignes directrices en matière de protection des données concernant le système d’alerte précoce et de réaction, lesquelles devraient contribuer à préciser les rôles, les tâches et les obligations des différentes personnes intervenant dans le système et, ainsi, à garantir le respect effectif des dispositions en matière de protection des données précitées et la fourniture d’informations claires et de dispositifs aisément accessibles aux personnes concernées pour qu’elles puissent faire valoir leurs droits,
#
# Example 3
# Source : Technologies The different technologies developed and utilized by the Agency are critical for maintaining adequate knowledge of the spread of disease both in Canada and globally.
# Predicted : Technologies Les différentes technologies mises au point et utilisées par l'Agence sont essentielles au maintien d'une connaissance adéquate de la propagation des maladies au Canada et à l'échelle mondiale.
# Reference : Technologies Les différentes technologies mises au point et utilisées par l'Agence sont essentielles pour maintenir un niveau de connaissances suffisant sur la propagation des maladies tant au Canada qu'à l'étranger.
#
# Example 4
# Source : In its reply regarding the comments of 21October 2006, the CBC conceded that the radio host's comments, including the use of the expression "notre ami, le Hassidique," were in very poor taste, ill-considered and uncalled for. The CBC expressed its regrets for the comments and discussed this very matter with its host so as to ensure that he clearly understood that even if there was no ill intent on his part, such remarks have no place on public radio.
# Predicted : Dans sa réponse au sujet des commentaires du 21octobre 2006, la SRC a admis que les commentaires de l'animateur de radio, y compris l'utilisation de l'expression « notre ami, le Hassidique », étaient de très mauvais goût, mal considérés et non réclamés. La SRC a exprimé ses regrets pour les commentaires et a discuté de cette question avec son hôte afin de s'assurer qu'il comprenait clairement que même s'il n'y avait pas de mauvaise intention de sa part, de telles remarques n'ont pas de place à la radio publique.
# Reference : Concernant les propos du 21 octobre 2006, la SRC concède que les propos de l'animateur, y compris de référer à lui comme «notre ami, le hassidique», sont de mauvais goût, peu polis et injustifiés. La SRC s'est excusée des propos et en a discuté avec l'animateur pour lui faire comprendre que, même si son intention n'était pas malicieuse, des remarques comme celles-là n'ont pas leur place à la radio.
#
# Example 5
# Source : Sensitivity analyses indicate that the extent of the unsupported length developed as a result of scour has a significant influence on the flexural pipe-soil response.
# Predicted : Les analyses de sensibilité indiquent que l'étendue de la longueur non soutenue développée à la suite de l'affouillement a une influence significative sur la réponse flexural tube-sol.
# Reference : Des analyses de sensibilité indiquent que l'importance de la longueur non supportée qui se développe à la suite de l'érosion a une influence significative sur la réaction conduite-sol en flexion.
#
# Example 6
# Source : I feel like my cock isn't big enough for you.
# Predicted : J'ai l'impression que ma bite n'est pas assez grande pour toi.
# Reference : J'ai l'impression que ma queue est trop petite pour toi.
#
# Example 7
# Source : Available online at: http://www.phac-aspc.gc.ca/ publicat/tbdrc03/index.html.
# Predicted : Disponible en ligne à l'adresse suivante : http://www.phac-aspc.gc.ca/publicat/tbdrc03/index.html.
# Reference : Disponible en ligne : http://www.phac-aspc.gc.ca/publicat/tbdrc03/index_f.html.
#
# Example 8
# Source : Bar patron found him.
# Predicted : Le patron du bar l'a trouvé.
# Reference : C'est le patron du bar qui l'a trouvé.
#
# Example 9
# Source : We must, however, realize that the greatest efforts by the developed countries will not suffice to halt climate change.
# Predicted : Nous devons cependant nous rendre compte que les efforts les plus importants des pays développés ne suffiront pas à enrayer les changements climatiques.
# Reference : Nous devons être conscients que les plus grands efforts déployés par les pays développés ne seront pas suffisants pour freiner les changements climatiques.
#
# Example 10
# Source : In other words, it approaches...
# Predicted : En d'autres termes, il s'approche...
# Reference : En d'autres termes, cela s'approche...
#
# Example 11
# Source : The European Union reiterates its readiness to coordinate its efforts with the parties involved and with its partners, in particular the Quartet members and countries in the region.
# Predicted : L'Union européenne réaffirme qu'elle est prête à coordonner ses efforts avec les parties concernées et avec ses partenaires, en particulier les membres du Quatuor et les pays de la région.
# Reference : L'Union européenne réaffirme qu'elle est prête à coordonner ses efforts avec les parties impliquées et avec ses partenaires, notamment les membres du Quatuor et les pays de la région.
#
# Example 12
# Source : It is important to emphasise that even after the transfers from the central subsidy fund, significant differences (up to 100%) in per-inhabitant revenue across local governments remain.
# Predicted : Il est important de souligner que même après les transferts du fonds central de subvention, il subsiste des différences significatives (jusqu'à 100%) dans les recettes par habitant entre les administrations locales.
# Reference : Il est important de noter que malgré les transferts effectués via ce fonds national, de fortes disparités de revenu par habitant, pouvant atteindre jusqu'à 100%, subsistent entre les collectivités locales.
#
# Example 13
# Source : The Minister Auguste welcomed with joy the visit of the Parliamentary Front, calling his creation "of initiative carrier for Haiti" and hoped that the links between parliamentarians latino-American and of Caribbean can be consolidated.
# Predicted : Le Ministre Auguste a accueilli avec joie la visite du Front parlementaire, appelant sa création « d'initiative porteuse pour Haïti » et a espéré que les liens entre parlementaires latino-américains et des Caraïbes puissent être consolidés.
# Reference : La Ministre Auguste a accueilli avec joie la visite de ce Front Parlementaire, qualifiant sa création « d’initiative porteuse pour Haïti » et souhaité que les liens entre les parlementaires latino-américains et caribéens puissent être consolidés.
#
# Example 14
# Source : The law on rural land tenure and nationality are very important, as noted by the Secretary-General in his most recent report on Côte d'Ivoire (S/2004/3).
# Predicted : La loi sur le régime foncier et la nationalité des zones rurales est très importante, comme l'a noté le Secrétaire général dans son dernier rapport sur la Côte d'Ivoire (S/2004/3).
# Reference : La loi sur le foncier rural et la nationalité sont, quant à elles aussi très importantes, comme en témoigne le Secrétaire général dans son dernier rapport sur la Côte d'Ivoire publié sous la cote S/2004/3.
#
# Example 15
# Source : The first-instance criminal court of Ain Sbaâ (Casablanca) found Belghouat guilty of “showing contempt” toward “public servants in the exercise of their duty,” with the intention of “undermining their honor,” under article 263 of the penal code, and “showing contempt” toward state institutions, under article 265.
# Predicted : Le tribunal pénal de première instance d'Ain Sbaâ (Casablanca) a déclaré Belghouat coupable de "montrer le mépris" à l'égard des fonctionnaires dans l'exercice de leurs fonctions, "avec l'intention de "sous-estimer leur honneur", "en vertu de l'article 263 du code pénal, et "montrer le mépris" à l'égard des institutions de l'État, en vertu de l'article 265.
# Reference : Le tribunal pénal de première instance de Aïn Sebâa (Casablanca) a déclaré Belghouat coupable d'avoir « outragé des fonctionnaires publics dans l'exercice de leur fonctions », avec l'intention de « porter atteinte à leur honneur », en vertu de l'article 263 du code pénal, et pour avoir « outragé des corps constitués » selon l'article 265.
#
# BLEU Score: 70.04860095521707
